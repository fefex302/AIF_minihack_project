# %%
import gym
import minihack
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as display

# %%
# quello che da errore è il secondo random (quindi l'ho tolto)

# %%
des_file = """
MAZE: "mylevel",' '
GEOMETRY:center,center
MAP
-------------
|.....|.....|
|.....|.....|
|.....+.....|
|.....|.....|
|.....|.....|
-------------
ENDMAP
REGION:(0,0,12,6),lit,"ordinary"
BRANCH:(1,1,6,6),(0,0,0,0)
DOOR:locked,(6,3)
MONSTER:'F',(2,3)
STAIR:(8,3),down
"""

# %%
des_file = """
MAZE: "mylevel", ' '
FLAGS:premapped
GEOMETRY:center,center

MAP
||||||||||    
|........|    
|........|    
|........|    
|LL......|    
|LL......|    
|||||.||||    
    |.||||||||
    |........|
    ||||||||||
ENDMAP

STAIR:(12, 8),down
BRANCH: (8,1,8,1),(9,2,9,2)
MONSTER: 'F', (1,1)
OBJECT: '%', (1,3)
"""

# %%
des_file = """
MAZE: "mylevel", ' '
FLAGS:premapped
GEOMETRY:center,center

MAP
       ||||||    
|||||  |....|    
|...|  |....|    
|...||||....|||||
|...L....||||...|
|LL...L.......L.|
|...||||||||.LL.|
|.LL|    |||.L..|
|...|    |.LLL.L|
|||||    |......|
         ||||||||
ENDMAP

STAIR:(10, 8),down
BRANCH: (1,8,1,8),(2,9,2,9)
MONSTER: random, (11,3)
MONSTER: random, (10,3)
MONSTER: random, (10,2)
MONSTER: random, (11,2)
MONSTER: random, (11,1)
MONSTER: random, (10,1)
MONSTER: random, (2,2)
MONSTER: random, (14,9)
"""

# %%
env = gym.make(
"MiniHack-Navigation-Custom-v0",
des_file=des_file,
max_episode_steps=50,
observation_keys=("chars", "pixel")
)

# %%
state = env.reset()
env.render()
# Out:
# Be careful!  New moon tonight.
#
#
#
#
#
#                                      ------
#                               -----  |....|
#                               |...|  |....|
#                               |...----....|----
#                               |...}....----...|
#                               |}}...}.......}.|
#                               |...--------.}}.|
#                               |.}}|    ---.}..|
#                               |@..|    |>}}}.}|
#                               -----    |......|
#                                        --------
#
#
#
#
#
# Agent the Footpad              St:18/01 Dx:18 Co:13 In:9 Wi:9 Ch:11 Chaotic S:0
# Dlvl:1 $:0 HP:12(12) Pw:2(2) AC:7 Xp:1/0

# %%
plt.imshow(state['pixel'][75:300, 450:800])

# %%
plt.imshow(state['chars'])

# %%
s, _, _, _ = env.step(3)
display.display(plt.gcf())
display.clear_output(wait=True)
# image.set_data(s['pixel'][75:300, 450:800])

# %%
state, _, _, _ = env.step(2)
plt.imshow(state['pixel'][75:300, 450:800])

# %%
plt.imshow(state['chars'])
