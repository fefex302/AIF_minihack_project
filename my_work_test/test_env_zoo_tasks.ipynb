# %%
import gym
import minihack
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as display

# %%
env = gym.make(
    "MiniHack-MazeWalk-Mapped-15x15-v0",
    observation_keys=("chars", "pixel")
)

# %%
state = env.reset()
env.render()
# Out:
# Be careful!  New moon tonight.
#
#
#
#
#
#                                 ..... ..... .
#                                 .     .   . .
#                                 ......... . .
#                                 .         . .
#                                 ..... .>... .
#                                     . .     .
#                                 ..... ... ...
#                                 .         @ .
#                                 . ....... . .
#                                 . .     .   .
#                                 ... . ... ...
#                                     . .   . .
#                                 ........... .
#
#
#
# Agent the Footpad              St:15 Dx:18 Co:12 In:11 Wi:10 Ch:9 Chaotic S:0
# Dlvl:1 $:0 HP:12(12) Pw:2(2) AC:7 Xp:1/0

# %%
plt.imshow(state['pixel'][75:300, 450:800])

# %%
plt.imshow(state['chars'][2:20, 30:50])
