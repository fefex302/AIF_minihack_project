# %%
import gym
import minihack
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as display

# %%
env = gym.make(
    "MiniHack-KeyRoom-S5-v0",
    observation_keys=("chars", "pixel")
)

# %%
state = env.reset()
env.render()
# Out:
# Be careful!  New moon tonight.
#
#
#
#
#
#
#
#
#                                          --
#                                          .|
#                                         ..|
#                                     --+-..|
#                                     |(.@..|
#                                     |.....|
#                                     -------
#
#
#
#
#
#
# Agent the Footpad              St:13 Dx:18 Co:14 In:13 Wi:11 Ch:6 Chaotic S:0
# Dlvl:1 $:0 HP:12(12) Pw:2(2) AC:7 Xp:1/0

# %%
plt.imshow(state['pixel'][100:275,550:700])
# plt.imshow(state['pixel'])

# %%
plt.imshow(state['chars'][5:15,30:45])
# plt.imshow(state['chars'])
